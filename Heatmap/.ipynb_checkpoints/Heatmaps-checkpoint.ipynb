# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt
import requests
import seaborn as sns
import json
import os
import datetime as dt
import re
import folium
from folium.plugins import HeatMap
import folium.plugins as plugins


from geopy import distance
from pandas.api.types import CategoricalDtype

# %% [markdown]
# # Helper Functions

# %%
m = folium.Map([-34.62, -58.4], zoom_start=12)

def crear_heatmap(df, labels): # labes = lat, lon y variable a plotear
    data_heat = df[labels]
    m = folium.Map([-34.62, -58.4], zoom_start=12)
    for i in range(len(df)):
        folium.Circle(
                location=[df.iloc[i][labels[0]], df.iloc[i][labels[1]]],
#                 print (location),
                radius=10,
    #             color = color,
                opacity=0.8,
    #             popup = ('Precio: ' + str(df.iloc[i].price_usd_per_m2).capitalize() + '<br>'
    #                      'Tipo de casa: ' + str(df.iloc[i].property_type) + '<br>'

                        ).add_to(m)
    
    m.add_child(HeatMap(data_heat, 
                        radius=8.4, 
                        min_opacity=1,
                        max_val =2,
                        blur=15,
                        gradient ={0.25: "blue", 
                                  0.50: "green",                              
                                  0.75: "yellow", 
                                  1: "red"                
                       }))
    folium.LayerControl().add_to(m)
    return m

# %% [markdown]
# # Armado de datasets

# %%
df = pd.read_csv("recorridos bicicleta/reducido_genero.csv", index_col="Unnamed: 0.1")
hombres = df.loc[df.genero_usuario=="M"]
mujeres = df.loc[df.genero_usuario=="F"]
df = df.drop(columns="Unnamed: 0" )
df.sort_index(inplace=True)

# %%
hombres = df.loc[df.genero_usuario == "M"]
mujeres = df.loc[df.genero_usuario == "F"]

# %% [markdown]
# ### Convirtiendo a variables datetime

# %%
df["fecha_origen_recorrido"] = pd.to_datetime(df['fecha_origen_recorrido'])
df["fecha_destino_recorrido"] = pd.to_datetime(df['fecha_destino_recorrido'])
df["duracion_recorrido"]= (df["fecha_destino_recorrido"]-df["fecha_origen_recorrido"])
# df["duracion_recorrido"]

# %% [markdown]
# # Distribución de la duracion de los viajes por genero

# %% [markdown]
# ### Preprocesamiento por genero

# %%
# # # Para hombres

hombres_populares_origen = hombres.groupby(by="id_estacion_origen").count()["periodo"].sort_values(ascending=False)
# hombres_populares
hombres_populares_destino = hombres.groupby(by="id_estacion_destino").count()["periodo"].sort_values(ascending=False)

hombres_populares = pd.DataFrame()
hombres_populares["origen"] = hombres_populares_origen
hombres_populares["destino"]=hombres_populares_destino
# hombres_populares.rename(columns={"periodo":"destino"})
hombres_populares["total"] =  hombres_populares["origen"] + hombres_populares["destino"]
hombres_populares["genero"] = "M"

hombres_top5_estaciones_origen = hombres_populares["origen"].sort_values().tail(5).index.tolist()
hombres_top5_estaciones_destino = hombres_populares["destino"].sort_values().tail(5).index.tolist()

# %%
# # # Para mujeres

mujeres_populares_origen = mujeres.groupby(by="id_estacion_origen").count()["periodo"].sort_values(ascending=False)
# hombres_populares
mujeres_populares_destino = mujeres.groupby(by="id_estacion_destino").count()["periodo"].sort_values(ascending=False)

mujeres_populares = pd.DataFrame()
mujeres_populares["origen"] = mujeres_populares_origen
mujeres_populares["destino"]= mujeres_populares_destino
# hombres_populares.rename(columns={"periodo":"destino"})
mujeres_populares["total"] =  mujeres_populares["origen"] + mujeres_populares["destino"]
mujeres_populares["genero"] = "F"

mujeres_top5_estaciones_origen = mujeres_populares["origen"].sort_values().tail(5).index.tolist()
mujeres_top5_estaciones_destino = mujeres_populares["destino"].sort_values().tail(5).index.tolist()

# %%
resultados_genero = pd.DataFrame({"cantidad_viajes": [hombres.shape[0], 
                                                      mujeres.shape[0]],
                                  "duracion_promedio":[hombres.duracion_recorrido.mean(),
                                                      mujeres.duracion_recorrido.mean()],
                                  "estaciones_origen_populares" : [hombres_top5_estaciones_origen,
                                                                   mujeres_top5_estaciones_origen],
                                  "estaciones_destino_populares" : [hombres_top5_estaciones_destino,
                                                                   mujeres_top5_estaciones_destino]}
                                )
resultados_genero = resultados_genero.rename(index={0:"Hombres",
                                                   1:"Mujeres"})
resultados_genero
# Out:
#          cantidad_viajes duracion_promedio estaciones_origen_populares  \
# Hombres           182849   00:29:37.207881           [29, 14, 8, 2, 9]
# Mujeres            67151   00:30:57.867850           [29, 1, 5, 14, 9]
#
#         estaciones_destino_populares
# Hombres             [8, 2, 1, 14, 9]
# Mujeres            [29, 5, 1, 14, 9]

# %%
# fig, (ax1, ax2) = plt.subplots(2, 2, figsize=(15, 15))

plt.figure(figsize=(8, 5))
sns.distplot(hombres["duracion_recorrido"])
sns.distplot(mujeres["duracion_recorrido"])
# Out:
# <AxesSubplot:xlabel='duracion_recorrido'>

# %%
# Extract the unique routes from the data with their start and end coordinates
maps = df[['Route Id', 'id_estacion_origen', 'lat_estacion_origen', 'long_estacion_origen', 'id_estacion_destino', 'lat_estacion_destino', 'long_estacion_destino']].drop_duplicates()
maps['Distance'] = maps.apply(lambda x: distance.distance((x['lat_estacion_origen'], x['long_estacion_origen']), (x["lat_estacion_destino"], x['long_estacion_destino'])).km * 1000, axis=1)

# Merge the distance calculation with the main DataFrame
df = df.merge(maps[['Route Id', 'Distance']], how='left', on='Route Id')
df = df[[x for x in df.columns if not 'From' in x and not 'To' in x and x != 'Route Id']]

# %%
fig, (ax1, ax2) = plt.subplots(2, 2, figsize=(15, 15))
for i, col in enumerate(['duracion_recorrido', 'Distance']):
    # Graph the distribution plots (seaborn doesn't allow default separation for distplot)
    for j, user in enumerate(df['genero_usuario'].unique()):
        sns.distplot(df[df['genero_usuario']==user][col], hist=False, ax=ax2[i])
    
    # Graph the boxplots
    sns.boxplot(x=col, y='genero_usuario', data=df, ax=ax1[i])
    ax1[i].set_xlabel('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-8615faf59f5d> in <module>
#       6
#       7     # Graph the boxplots
# ----> 8     sns.boxplot(x=col, y='genero_usuario', data=df, ax=ax1[i])
#       9     ax1[i].set_xlabel('')
#
# ~\.conda\envs\dhdsblend\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2245     kwargs.update(dict(whis=whis))
#    2246
# -> 2247     plotter.plot(ax, kwargs)
#    2248     return ax
#    2249
#
# ~\.conda\envs\dhdsblend\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     544     def plot(self, ax, boxplot_kws):
#     545         """Make the plot."""
# --> 546         self.draw_boxplot(ax, boxplot_kws)
#     547         self.annotate_axes(ax)
#     548         if self.orient == "h":
#
# ~\.conda\envs\dhdsblend\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     481                                          positions=[i],
#     482                                          widths=self.width,
# --> 483                                          **kws)
#     484                 color = self.colors[i]
#     485                 self.restyle_boxplot(artist_dict, color, props)
#
# ~\.conda\envs\dhdsblend\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\.conda\envs\dhdsblend\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3785                            meanline=meanline, showfliers=showfliers,
#    3786                            capprops=capprops, whiskerprops=whiskerprops,
# -> 3787                            manage_ticks=manage_ticks, zorder=zorder)
#    3788         return artists
#    3789
#
# ~\.conda\envs\dhdsblend\lib\site-packages\matplotlib\axes\_axes.py in bxp(self, bxpstats, positions, widths, vert, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder)
#    4082             if showbox:
#    4083                 if patch_artist:
# -> 4084                     boxes.extend(dopatch(box_x, box_y, **final_boxprops))
#    4085                 else:
#    4086                     boxes.extend(doplot(box_x, box_y, **final_boxprops))
#
# ~\.conda\envs\dhdsblend\lib\site-packages\matplotlib\axes\_axes.py in dopatch(xs, ys, **kwargs)
#    4016             def dopatch(xs, ys, **kwargs):
#    4017                 xs, ys = ys, xs  # flip X, Y
# -> 4018                 return patch_list(xs, ys, **kwargs)
#    4019
#    4020         # input validation
#
# ~\.conda\envs\dhdsblend\lib\site-packages\matplotlib\axes\_axes.py in patch_list(xs, ys, **kwargs)
#    3993             path = mpath.Path(
#    3994                 # Last vertex will have a CLOSEPOLY code and thus be ignored.
# -> 3995                 np.append(np.column_stack([xs, ys]), [(0, 0)], 0),
#    3996                 closed=True)
#    3997             patch = mpatches.PathPatch(path, **kwargs)
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~\.conda\envs\dhdsblend\lib\site-packages\numpy\lib\shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('<m8[ns]') according to the rule 'same_kind'

# %%
df_conid = df.copy()
df_conid.dropna(subset=['id_usuario'], how='all', inplace=True)

# %%
# Create the day of week Category by iterrating over 7 days (March 4th, 2019 is a Monday)
days = [(dt.datetime(2019, 3, 4) + dt.timedelta(days=x)).strftime('%a') for x in range(0, 7)]
day_type = CategoricalDtype(categories=days, ordered=True)

# Create the month Category by iterrating over the months
months = [dt.datetime(2019, x, 1).strftime('%B') for x in range(1, 13)]
month_type = CategoricalDtype(categories=months, ordered=True)

# %%
# Out:
# Unnamed: 0.1
# 0          2019-01-01 00:01:16
# 15         2019-01-01 01:00:45
# 24         2019-01-01 01:16:38
# 26         2018-01-01 01:12:28
# 45         2018-01-01 01:47:29
#                   ...
# 2619900    2018-12-30 19:08:22
# 2619919    2018-12-30 19:16:59
# 2619927    2018-12-30 19:21:14
# 2619948    2018-12-30 19:37:44
# 2619962    2018-12-30 19:45:39
# Name: fecha_origen_recorrido, Length: 161487, dtype: object

# %%
df_conid['Date'] = df_conid['fecha_origen_recorrido'].apply(lambda x: x.date)

# %%
df_conid['Date'] = df_conid['fecha_origen_recorrido'].apply(lambda x: x.strftime('%Y-%m-%d'))
df_conid['Quarter'] = df_conid['fecha_origen_recorrido'].apply(lambda x: int((int(x.strftime('%m')) - 1) / 3) + 1)
df_conid['Month'] = df_conid['fecha_origen_recorrido'].apply(lambda x: x.strftime('%B')).astype(month_type)
df_conid['Day of Week'] = df_conid['fecha_origen_recorrido'].apply(lambda x: x.strftime('%a')).astype(day_type)
df_conid['Hour'] = df_conid['fecha_origen_recorrido'].apply(lambda x: x.strftime('%H'))

# %%
# Aggregate the ridership by date fields and user type and count the number of unique trips
ridership = df_conid.groupby(['Date', 'Quarter', 'Month', 'Day of Week', 'genero_usuario'])['id_usuario']\
              .nunique().reset_index().sort_values('Date', ascending=True)

# %%
p = sns.relplot(x='Date', y='id_usuario', hue='genero_usuario', data=ridership, kind='line', height=9, aspect=16/9.)
p.ax.set_ylabel('Total Daily Trips')

# Limit the number of labels shown on the x-axis to only show the first day of each month
p.ax.set_xticklabels([x.set_text('') if not x.get_text().endswith('-01') else x for x in p.ax.get_xticklabels()], rotation=45)
p.show()
# Out:
# C:\Users\Iago\.conda\envs\dhdsblend\lib\site-packages\ipykernel_launcher.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   """
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-248-130d2b013047> in <module>
#       4 # Limit the number of labels shown on the x-axis to only show the first day of each month
#       5 p.ax.set_xticklabels([x.set_text('') if not x.get_text().endswith('-01') else x for x in p.ax.get_xticklabels()], rotation=45)
# ----> 6 p.show()
#
# AttributeError: 'FacetGrid' object has no attribute 'show'

# %% [markdown]
# ### Datasets por destino u origen

# %%
df_origen = df.groupby("id_estacion_origen")
viajes_por_origen = df_origen.count()["periodo"]
viajes_por_origen
# Out:
# id_estacion_origen
# 1      3948
# 2      4706
# 3      1565
# 4      2186
# 5      3977
#        ...
# 196     270
# 197     727
# 198     149
# 199    1014
# 200    1300
# Name: periodo, Length: 198, dtype: int64

# %%
estaciones_origen = df[['id_estacion_origen', 'nombre_estacion_origen', 'long_estacion_origen',
       'lat_estacion_origen', 'domicilio_estacion_origen']]
estaciones_origen = estaciones_origen.drop_duplicates(subset=("id_estacion_origen")).sort_values("id_estacion_origen").reset_index()
estaciones_origen=estaciones_origen.set_index("id_estacion_origen")#.drop(columns="index")
estaciones_origen["cant_viajes"] =viajes_por_origen

# %%
df_destino = df.groupby("id_estacion_destino")
viajes_por_destino = df_destino.count()["periodo"]
viajes_por_destino
# Out:
# id_estacion_destino
# 1      4614
# 2      3859
# 3      1661
# 4      2186
# 5      3882
#        ...
# 196     266
# 197     688
# 198     121
# 199    1070
# 200    1328
# Name: periodo, Length: 198, dtype: int64

# %%
estaciones_destino = df[['id_estacion_destino',
       'nombre_estacion_destino', 'long_estacion_destino',
       'lat_estacion_destino', 'domicilio_estacion_destino']]
estaciones_destino = estaciones_destino.drop_duplicates(subset=("id_estacion_destino")).sort_values("id_estacion_destino").reset_index()
estaciones_destino=estaciones_destino.set_index("id_estacion_destino")#.drop(columns="index")
estaciones_destino["cant_viajes"] = viajes_por_destino

# %% [markdown]
# # Creacion de heatmaps

# %% [markdown]
# ## Promedio historico

# %% [markdown]
# ### Origen

# %%
crear_heatmap(estaciones_origen, ['lat_estacion_origen', 'long_estacion_origen', "cant_viajes" ])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Destino

# %%
crear_heatmap(estaciones_destino, ['lat_estacion_destino', 'long_estacion_destino', "cant_viajes" ])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Tipos de estacion (sin diferenciar horario)

# %%
tipos_de_estacion = (viajes_por_origen - viajes_por_destino)
tipos_de_estacion.sort_values(ascending=False)
# quantiles = tipos_de_estacion.quantile(q=[0.05, 0.25, .5, .75, 0.95])
# quantiles.tolist()
categorias_estacion = pd.qcut(tipos_de_estacion, q=[0, 0.05, 0.25, .75, 0.95, 1], 
                              labels=["Extremo destino", "Destino", "Ambas", "Origen", "Extremo origen"])

categorias_estacion.value_counts()
# Out:
# Ambas              97
# Destino            41
# Origen             40
# Extremo origen     10
# Extremo destino    10
# Name: periodo, dtype: int64

# %% [markdown]
# # Hetmaps con tiempo

# %% [markdown]
# ### Estaciones de origen

# %%
# # # # # Origen

estaciones_origen = df[['id_estacion_origen', 'nombre_estacion_origen', 'long_estacion_origen',
       'lat_estacion_origen', 'domicilio_estacion_origen']]
estaciones_origen = estaciones_origen.drop_duplicates(subset=("id_estacion_origen")).sort_values("id_estacion_origen").reset_index()
estaciones_origen=estaciones_origen.set_index("id_estacion_origen")#.drop(columns="index")

df["hour"] = df.fecha_origen_recorrido.dt.hour
groupby_viajes_hora_origen = df.groupby(["id_estacion_origen", "hour"])["periodo"].count().unstack(1).replace(np.nan, 0)
groupby_viajes_hora_origen[['lat_estacion_origen', 'long_estacion_origen']] = estaciones_origen [['lat_estacion_origen', 'long_estacion_origen']]
# groupby_viajes_hora_origen

# %%
### Cada fila es una hora, y cada columna es una estacion
heatmap_origen = pd.DataFrame()
for hora in range (0, 24):
    heatmap_origen[hora] = groupby_viajes_hora_origen.apply(lambda x: [x["lat_estacion_origen"], 
                                                     x["long_estacion_origen"], 
                                                     int(x[hora])/100], axis=1) # 
heatmap_origen = heatmap_origen.transpose()
# heatmap_origen

# %%
from datetime import datetime, timedelta
sr = pd.Series(pd.date_range('2020-7-12 1:00', 
                       periods = 24, freq = 'H')) 

array_origen = heatmap_origen.to_numpy().tolist()

m = folium.Map([-34.62, -58.4], zoom_start=12)

hm = plugins.HeatMapWithTime(array_origen, 
#                              index=sr, # Que lista de horarios toma para avanzar
                             auto_play=True, 
                             max_opacity=0.3)

hm.add_to(m)

m.save("heatmaps/heatmap_origen.html")

# %% [markdown]
# ## Destino

# %%
# # # # # # Destino

estaciones_destino = df[['id_estacion_destino', 'nombre_estacion_destino', 'long_estacion_destino',
       'lat_estacion_destino', 'domicilio_estacion_destino']]
estaciones_destino = estaciones_destino.drop_duplicates(subset=("id_estacion_destino")).sort_values("id_estacion_destino").reset_index()
estaciones_destino=estaciones_destino.set_index("id_estacion_destino")#.drop(columns="index")

df["hour"] = df.fecha_destino_recorrido.dt.hour
groupby_viajes_hora_destino = df.groupby(["id_estacion_destino", "hour"])["periodo"].count().unstack(1).replace(np.nan, 0)
groupby_viajes_hora_destino[['lat_estacion_destino', 'long_estacion_destino']] = estaciones_destino [['lat_estacion_destino', 'long_estacion_destino']]
# groupby_viajes_hora_destino

# %%
### Cada fila es una hora, y cada columna es una estacion
heatmap_destino = pd.DataFrame()
for hora in range (0, 24):
    heatmap_destino[hora] = groupby_viajes_hora_destino.apply(lambda x: [x["lat_estacion_destino"], 
                                                     x["long_estacion_destino"], 
                                                     int(x[hora])/100], axis=1) # 
heatmap_destino = heatmap_destino.transpose()

# %%
from datetime import datetime, timedelta
sr = pd.Series(pd.date_range('2020-7-12 1:00', 
                       periods = 24, freq = 'H')) 

array_destino = heatmap_destino.to_numpy().tolist()

m = folium.Map([-34.62, -58.4], zoom_start=12)

hm = plugins.HeatMapWithTime(array_destino, 
#                              index=sr, # Que lista de horarios toma para avanzar
                             auto_play=True, 
                             max_opacity=0.3)

hm.add_to(m)

m.save("heatmaps/heatmap_destino.html")

# %% [markdown]
# # Ejemplo

# %%
from datetime import datetime, timedelta

time_index = [
    (datetime.now() + k * timedelta(1)).strftime("%Y-%m-%d") for k in range(len(data))
]

m = folium.Map([48.0, 5.0], tiles="stamentoner", zoom_start=6)

hm = plugins.HeatMapWithTime(data, 
                             index=time_index, # Que lista de horarios toma para aa
                             auto_play=True, 
                             max_opacity=0.3)

hm.add_to(m)

# m
